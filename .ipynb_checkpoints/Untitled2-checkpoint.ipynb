# %%
import os
list_of_files = {}
datas = []
for dirpath,dirnames,filenames in os.walk("F:/CST17020/python/ImageProcessingProject/my extra works/labels"):
    for filename in filenames:
        if filename.endswith('.txt'): 
            list_of_files[filename] = os.sep.join([dirpath, filename])
            file = open(os.path.join(dirpath, filename), 'r')
#             file.read()
            data = file.readlines()
            datas.append(data)
#             datas.append(data)
            file.close()
#             print(data)
print(datas)

# for (roots,dirname,files) in os.walk('F:/CST17020/python/myProject/labels')
# for f in files:
#     outfile = open(f,'r')
#     data = outfile.readlines()
# Out:
# [['Mr.Fazni M.F.M\n', 'UWU/CST/17/020\n', 'Science & Technology\n', 'Computer Science &\n', 'Technology'], ['Ms. Nabeela M.I\n', 'UWU/CST/17/038 \n', 'Science & Technology \n', 'Computer Science & \n', 'Technology'], ['Mr. Shihan N.S\n', 'UWU/SCT/17/O44\n', 'Science & Technology\n', 'Science & Technology'], ['Mr. Musharrirf M.M.M.\n', 'UWU/IIT/17/033\n', 'Science & Technology\n', 'Industrial Information\n', 'Technology'], ['Ms. Yasora R.M.V.\n', 'UWU/CST/17/068\n', 'Science & Technology\n', 'Computer Science &\n', 'Technology'], ['Ms. Kunapala N.\n', 'UWU/CST/17/O35\n', 'Science & Technology\n', 'Computer Science &\n', 'Technology'], ['Mr. Dalpathadu K.P.K.G.\n', 'UWU/CST/17/011\n', 'Science & Technology\n', 'Computer Science &.\n', 'Technology']]

# %%
from imutils import paths
import cv2

imagesPaths = list(paths.list_images('F:/CST17020/python/ImageProcessingProject\my extra works/id'))
print(imagesPaths)
# Out:
# ['F:/CST17020/python/myProject/id\\1.jpg', 'F:/CST17020/python/myProject/id\\2.jpg', 'F:/CST17020/python/myProject/id\\3.jpg', 'F:/CST17020/python/myProject/id\\4.jpg', 'F:/CST17020/python/myProject/id\\5.jpg', 'F:/CST17020/python/myProject/id\\6.jpg', 'F:/CST17020/python/myProject/id\\7.jpg']

# %%
import pandas as pd
df = pd.DataFrame(imagesPaths)

# %%
df
# Out:
#                                        0
# 0  F:/CST17020/python/myProject/id\1.jpg
# 1  F:/CST17020/python/myProject/id\2.jpg
# 2  F:/CST17020/python/myProject/id\3.jpg
# 3  F:/CST17020/python/myProject/id\4.jpg
# 4  F:/CST17020/python/myProject/id\5.jpg
# 5  F:/CST17020/python/myProject/id\6.jpg
# 6  F:/CST17020/python/myProject/id\7.jpg

# %%
df2 = pd.DataFrame(datas)

# %%
df2
# Out:
#                            0                  1                        2  \
# 0           Mr.Fazni M.F.M\n   UWU/CST/17/020\n   Science & Technology\n
# 1          Ms. Nabeela M.I\n  UWU/CST/17/038 \n  Science & Technology \n
# 2           Mr. Shihan N.S\n   UWU/SCT/17/O44\n   Science & Technology\n
# 3    Mr. Musharrirf M.M.M.\n   UWU/IIT/17/033\n   Science & Technology\n
# 4        Ms. Yasora R.M.V.\n   UWU/CST/17/068\n   Science & Technology\n
# 5          Ms. Kunapala N.\n   UWU/CST/17/O35\n   Science & Technology\n
# 6  Mr. Dalpathadu K.P.K.G.\n   UWU/CST/17/011\n   Science & Technology\n
#
#                           3           4
# 0      Computer Science &\n  Technology
# 1     Computer Science & \n  Technology
# 2      Science & Technology        None
# 3  Industrial Information\n  Technology
# 4      Computer Science &\n  Technology
# 5      Computer Science &\n  Technology
# 6     Computer Science &.\n  Technology

# %%
df_all_rows = pd.concat([df, df2],axis=1)

# %%
df_all_rows
# Out:
#                                        0                          0  \
# 0  F:/CST17020/python/myProject/id\1.jpg           Mr.Fazni M.F.M\n
# 1  F:/CST17020/python/myProject/id\2.jpg          Ms. Nabeela M.I\n
# 2  F:/CST17020/python/myProject/id\3.jpg           Mr. Shihan N.S\n
# 3  F:/CST17020/python/myProject/id\4.jpg    Mr. Musharrirf M.M.M.\n
# 4  F:/CST17020/python/myProject/id\5.jpg        Ms. Yasora R.M.V.\n
# 5  F:/CST17020/python/myProject/id\6.jpg          Ms. Kunapala N.\n
# 6  F:/CST17020/python/myProject/id\7.jpg  Mr. Dalpathadu K.P.K.G.\n
#
#                    1                        2                         3  \
# 0   UWU/CST/17/020\n   Science & Technology\n      Computer Science &\n
# 1  UWU/CST/17/038 \n  Science & Technology \n     Computer Science & \n
# 2   UWU/SCT/17/O44\n   Science & Technology\n      Science & Technology
# 3   UWU/IIT/17/033\n   Science & Technology\n  Industrial Information\n
# 4   UWU/CST/17/068\n   Science & Technology\n      Computer Science &\n
# 5   UWU/CST/17/O35\n   Science & Technology\n      Computer Science &\n
# 6   UWU/CST/17/011\n   Science & Technology\n     Computer Science &.\n
#
#             4
# 0  Technology
# 1  Technology
# 2        None
# 3  Technology
# 4  Technology
# 5  Technology
# 6  Technology
